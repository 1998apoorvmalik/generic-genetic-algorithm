# %%
from genetic_algorithm import GeneticAlgorithm
from n_queens_problem import NQueensExample
from fifteen_puzzle_problem import FifteenPuzzleExample
from eight_puzzle_problem import EightPuzzleExample
from fifteen_puzzle_problem import FifteenPuzzleExample
from correct_string_example import CorrectStringExample

# %%
target_string = CorrectStringExample(string = "WEOFNWEljfnbwe ewfnwoenfoi eWEOFPUNBweioufbipuweBFPOWnfvownVOJNWE")
target_string.show_documentation()
# Out:
# 					GENETIC ALGORITHM
#
#
# You don't need to execute any method other than self.run_simulation(), (p.s: try it at your own risk).
# The following Genetic Algorithm implementation provides multiple options for the selection, crossover
# and mutation steps, below is the definition for various arguments that you can use for these methods.
# It may be a better practice to pass these arguments in the form of a dictionary, for eg:
# self.run_simulation(**kwargs). It is not compulsory to provide these arguments at all, as default values are
# already provided for them.
#
#
# Argument : population_size : Specifies population size for each generation.
#
# Argument : stats_frequency : Specifies how frequently should the simulation statistics
# be displayed.
#
#
# Selection methods, and corresponding arguments ->
#
# Argument : selection_type = 'a' : Returns the most fittest and second most fittest genotype.
#
# ...

# %%
kwargs = {"population_size":100, "stats_frequency":100, "selection_type":'a', "crossover_type_1":'a',\
          "crossover_type_2":'a', "mutation_type":'e', "mutation_type_e_prob":0.01}
_, _ = target_string.run_simulation(**kwargs)
# Out:
# Target Fitness = 65
# Simulation started with following options:
#
# 1)	Type 'a' Selection method
# 2)	Single Point Crossover method
# 3)	Probability Random Resetting Mutation method, with mutation probability = 0.01
#
# Generation : 1, Population size = 100, Max population fitness = 3, Avg. population fitness = 1.5
# Generation : 100, Population size = 100, Max population fitness = 26, Avg. population fitness = 24.79
# Generation : 200, Population size = 100, Max population fitness = 39, Avg. population fitness = 36.55
# Generation : 300, Population size = 100, Max population fitness = 45, Avg. population fitness = 44.11
# Generation : 400, Population size = 100, Max population fitness = 50, Avg. population fitness = 48.52
# Generation : 500, Population size = 100, Max population fitness = 57, Avg. population fitness = 55.86
# Generation : 600, Population size = 100, Max population fitness = 59, Avg. population fitness = 55.45
# ...

# %%
n_queen = NQueensExample(8, display_documentation=False)
kwargs = {"population_size":16, "stats_frequency":100, "selection_type":'a', "crossover_type_1":'a',\
          "crossover_type_2":'a', "mutation_type":'a', "mutation_type_e_prob":0.01}
n_queen.run_simulation(**kwargs)
# Out:
# Target Fitness = 28
# Simulation started with following options:
#
# 1)	Type 'a' Selection method
# 2)	Single Point Crossover method
# 3)	Random Resetting mutation method
#
# Generation : 1, Population size = 16, Max population fitness = 25, Avg. population fitness = 19.9375
#
# Solution found after 52 generations, Max population fitness = 28, Avg. population fitness = 25.3125
#
# board : [6, 4, 2, 8, 5, 7, 1, 3]
# * * * * * Q * *
# * * * Q * * * *
# * Q * * * * * *
# * * * * * * * Q
# * * * * Q * * *
# * * * * * * Q *
# Q * * * * * * *
# * * Q * * * * *
# Fitness: 28
# ([[6, 4, 2, 8, 5, 7, 8, 3],
#   [6, 4, 1, 8, 5, 7, 3, 3],
#   [6, 4, 1, 8, 5, 3, 8, 3],
#   [6, 4, 2, 8, 5, 6, 1, 3],
#   [6, 4, 2, 8, 5, 7, 8, 3],
#   [6, 4, 2, 8, 5, 7, 1, 3],
#   [6, 4, 2, 8, 5, 7, 1, 4],
#   [6, 4, 1, 7, 5, 7, 8, 3],
#   [6, 4, 1, 8, 5, 7, 5, 3],
#   [6, 4, 7, 8, 5, 7, 1, 3],
#   [6, 4, 1, 5, 5, 7, 8, 3],
#   [6, 5, 2, 8, 5, 7, 1, 3],
#   [6, 4, 3, 8, 5, 7, 8, 3],
#   [6, 4, 1, 7, 5, 7, 1, 3],
# ...

# %%
puzzle_eight = EightPuzzleExample(display_documentation=False)
puzzle_eight.run_simulation()
# Out:
# Target Fitness = 0
# Simulation started with following options:
#
# 1)	Type 'a' Selection method
# 2)	Single Point Crossover method
# 3)	Random Resetting mutation method
#
# Generation : 1, Population size = 10, Max population fitness = -10, Avg. population fitness = -14.2
# Generation : 100, Population size = 10, Max population fitness = -6, Avg. population fitness = -6.2
# Generation : 200, Population size = 10, Max population fitness = -4, Avg. population fitness = -9.6
# Generation : 300, Population size = 10, Max population fitness = -6, Avg. population fitness = -8.4
# Generation : 400, Population size = 10, Max population fitness = -8, Avg. population fitness = -9.2
# Generation : 500, Population size = 10, Max population fitness = -6, Avg. population fitness = -7.4
# Generation : 600, Population size = 10, Max population fitness = -6, Avg. population fitness = -6.0
# Generation : 700, Population size = 10, Max population fitness = -4, Avg. population fitness = -8.6
#
# ...
